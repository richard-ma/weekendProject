# %% [markdown]
# # 正态分布及其应用

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats

from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

# %precision 3
# %matplotlib inline

# %%
# 圆周率

np.pi
# Out:
# 3.142

# %%
# 自然对数
np.exp(1)
# Out:
# 2.718

# %%
# 概率密度
x = 3
mu = 4
sigma = 0.8

1 / (np.sqrt(2 * np.pi * sigma**2)) * \
    np.exp(-((x-mu)**2) / (2 * sigma**2))
# Out:
# 0.228

# %%
stats.norm.pdf(loc=4, scale=0.8, x=3)
# Out:
# 0.228

# %%
# 绘制概率密度图形

x_plot = np.arange(start=1, stop=7.1, step=0.1)
plt.plot(
    x_plot,
    stats.norm.pdf(x=x_plot, loc=4, scale=0.8),
    color='black'
)

# %% [markdown]
# * 累积分布函数 cdf (cumulative distribution function)
# * 百分位数 ppf (percent point function)

# %%
stats.norm.cdf(loc=4, scale=0.8, x=3)
# Out:
# 0.106

# %%
stats.norm.ppf(loc=4, scale=0.8, q=0.106)
# Out:
# 3.002

# %% [markdown]
# * 标准正态分布 均值为0，方差为1的正态分布
# * t值：（样本均值-总体均值）/ 标准误差

# %%
# t值

np.random.seed(1)
t_value_array = np.zeros(10000)
norm_dist = stats.norm(loc=4, scale=0.8)

for i in range(0, 10000):
    sample = norm_dist.rvs(size=10)
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)
    sample_se = sample_std / np.sqrt(len(sample))
    t_value_array[i] = (sample_mean - 4) / sample_se

x = np.arange(start=-8, stop=8.1, step=0.1)
plt.plot(x, stats.norm.pdf(x=x), color="black", linestyle="dotted")
sns.histplot(t_value_array, color="gray")
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# * t分布：在总体方差未知的情况下也可以研究样本均值的分布

# %%
plt.plot(x, stats.norm.pdf(x=x), color="black", linestyle="dotted")
plt.plot(x, stats.t.pdf(x=x, df=9), color="black")
